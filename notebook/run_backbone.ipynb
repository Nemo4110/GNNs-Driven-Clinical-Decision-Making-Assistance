# %% [markdown]
# # Install necessary packages

# %%
# !pip uninstall -q torchtext pandas-stubs -y

# !pip install -q torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install -q torch_geometric -f https://data.pyg.org/whl/torch-1.12.1+cu113.html
# !pip install -q d2l tqdm scikit-learn dill torcheval Deprecated
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 87.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 88.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 109.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 105.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 118.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 69.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Git operations

# %%
# %cd /content/drive/MyDrive/proj/LERS
# Out:
# /content/drive/MyDrive/proj/LERS

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0
# Unpacking objects: 100% (5/5), 1.65 KiB | 0 bytes/s, done.
# From https://github.com/Nemo4110/LERS
#  * [new branch]      refactor-predictor-with-mha -> origin/refactor-predictor-with-mha
# Already up to date.

# %%
# !git branch

# %%
# !git checkout add-baseline-recommenders
# !git checkout refactor-predictor-with-mha
# Out:
# Updating files: 100% (6/6), done.
# Switched to branch 'add-baseline-recommenders'
# Your branch is up to date with 'origin/add-baseline-recommenders'.

# %%
# !git rev-parse HEAD
# Out:
# e806ff4ce22302742640de0f6816185e26c00cef

# %% [markdown]
# ## reset curr local branch sync with remote corresponding branch

# %%
# !git fetch --all

# %%
# !git reset --hard origin/add-baseline-recommenders

# %% [markdown]
# # RUN!

# %% [markdown]
# ## Train

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_backbone.py --goal="drug" --train --use_gpu --gnn_type="GENConv" --num_encoder_layers=1
# !python run_backbone.py --goal="drug" --train --use_gpu --gnn_type="GENConv"
# !python run_backbone.py --goal="drug" --train --use_gpu --gnn_type="GATConv"

# !python run_backbone.py --goal="drug" --train --use_gpu --gnn_type="GINEConv" --gnn_layer_num=3
# !python run_backbone.py --goal="drug" --train --use_gpu --gnn_type="GINEConv" --gnn_layer_num=2  # BEST PERF
# !python run_backbone.py --goal="drug" --train --use_gpu --gnn_type="GINEConv" --gnn_layer_num=1

# !python run_backbone.py --goal="drug" --train --use_gpu --gnn_type="GINEConv" --item_type="drug"  # GNN仅使用与drug结点有关的信息
# !python run_backbone.py --goal="drug" --train --use_gpu --gnn_type="GINEConv" --is_gnn_only

# !python run_backbone.py --goal="labitem" --train --use_gpu --gnn_type="GINEConv"
# !python run_backbone.py --goal="labitem" --train --use_gpu --gnn_type="GINEConv" --item_type="labitem"  # GNN仅使用与labitem结点有关的信息
# !python run_backbone.py --goal="labitem" --train --use_gpu --gnn_type="GINEConv" --is_gnn_only
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# avg. train loss: 0.1310

# %% [markdown]
# ## Test

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_backbone.py --goal="drug" --test --use_gpu --num_encoder_layers=1 --model_ckpt="loss_0.1687_BackBoneV2_goal_drug.pt"
# !python run_backbone.py --goal="drug" --test --use_gpu --is_gnn_only --model_ckpt="loss_0.1445_BackBoneV2_goal_drug.pt"
# !python run_backbone.py --goal="drug" --test --use_gpu --item_type="drug" --model_ckpt="loss_0.1503_BackBoneV2_goal_drug.pt"

# !python run_backbone.py --goal="drug" --test --use_gpu --gnn_type="GATConv" --model_ckpt="loss_0.2503_BackBoneV2_goal_drug.pt"

# !python run_backbone.py --goal="drug" --test --use_gpu --gnn_type="GINEConv" --gnn_layer_num=3 --model_ckpt="loss_0.1307_BackBoneV2_goal_drug.pt"
# !python run_backbone.py --goal="drug" --test --use_gpu --gnn_type="GINEConv" --gnn_layer_num=2 --model_ckpt="loss_0.1303_BackBoneV2_goal_drug.pt"
# !python run_backbone.py --goal="drug" --test --use_gpu --gnn_type="GINEConv" --gnn_layer_num=1 --model_ckpt="loss_0.1305_BackBoneV2_goal_drug.pt"
# !python run_backbone.py --goal="drug" --test --use_gpu --gnn_type="GINEConv" --is_gnn_only --model_ckpt="loss_0.1220_BackBoneV2_goal_drug.pt"

# !python run_backbone.py --goal="drug" --test --use_gpu --gnn_type="GINEConv" --item_type="drug" --model_ckpt="loss_0.1306_BackBoneV2_goal_drug.pt"

# !python run_backbone.py --goal="labitem" --test --use_gpu --gnn_type="GINEConv" --model_ckpt="loss_0.1167_BackBoneV2_goal_labitem.pt"
# !python run_backbone.py --goal="labitem" --test --use_gpu --gnn_type="GINEConv" --item_type="labitem" --model_ckpt="loss_0.1173_BackBoneV2_goal_labitem.pt"
# !python run_backbone.py --goal="labitem" --test --use_gpu --gnn_type="GINEConv" --is_gnn_only --model_ckpt="loss_0.1141_BackBoneV2_goal_labitem.pt"

# !python run_backbone.py --goal="labitem" --test --use_gpu --model_ckpt="loss_0.1638_BackBoneV2_goal_labitem.pt"
# !python run_backbone.py --goal="labitem" --test --use_gpu --item_type="labitem" --model_ckpt="loss_0.1280_BackBoneV2_goal_labitem.pt"
# !python run_backbone.py --goal="labitem" --test --use_gpu --is_gnn_only --model_ckpt="loss_0.1251_BackBoneV2_goal_labitem.pt"
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# using saved model: loss_0.1306_BackBoneV2_goal_drug.pt
