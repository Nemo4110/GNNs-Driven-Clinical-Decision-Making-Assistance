# %%
# !pip uninstall -q torchtext pandas-stubs -y

# !pip install -q torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install -q torch_geometric -f https://data.pyg.org/whl/torch-1.12.1+cu113.html
# !pip install -q d2l tqdm scikit-learn dill torcheval Deprecated
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 44.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 106.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 105.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 121.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 65.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 9.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xgboost 2.1.1 requires nvidia-nccl-cu12; platform_system == "Linux" and platform_machine != "aarch64", which is not installed.
# albucore 0.0.13 requires numpy<2,>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.13 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.0.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.

# %% [markdown]
# # Git operations

# %%
# %cd /content/drive/MyDrive/proj/LERS
# Out:
# /content/drive/MyDrive/proj/LERS

# %%
# !git pull

# %%
# !git branch

# %%
# !git checkout add-baseline-recommenders
# Out:
# Switched to branch 'add-baseline-recommenders'
# Your branch is up to date with 'origin/add-baseline-recommenders'.

# %%
# !git rev-parse HEAD

# %%
# !git fetch --all
# !git reset --hard origin/add-baseline-recommenders
# Out:
# Fetching origin
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 6 (delta 5), reused 6 (delta 5), pack-reused 0
# Unpacking objects: 100% (6/6), 736 bytes | 24.00 KiB/s, done.
# From https://github.com/Nemo4110/LERS
#  + fd69fb2...4437de9 add-baseline-recommenders -> origin/add-baseline-recommenders  (forced update)
# HEAD is now at 4437de9 1. fix SASRec中，关于`item_seq_len`与`gather_indexes`的bug 2. fix eval stage的逻辑错误

# %% [markdown]
# # Train

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_baseline.py --goal="drug" --train --use_gpu --model_name=DIN
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# avg. train loss: 0.1745

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_baseline.py --goal="labitem" --train --use_gpu --model_name=SASRec --batch_size=2048
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# avg. train loss: 0.1341

# %% [markdown]
# # Test

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_baseline.py --goal="drug" --test --use_gpu --model_name=DIN --model_ckpt="loss_0.0973_DIN_goal_drug.pt"
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# using saved model: loss_0.0973_DIN_goal_drug.pt

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_baseline.py --goal="labitem" --test --use_gpu --model_name=DIN --model_ckpt="loss_0.1230_DIN_goal_labitem.pt"
# !python run_baseline.py --goal="labitem" --test --use_gpu --model_name=SASRec --batch_size=2048 --model_ckpt="loss_0.1297_SASRec_goal_labitem.pt"
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# using saved model: loss_0.1297_SASRec_goal_labitem.pt
