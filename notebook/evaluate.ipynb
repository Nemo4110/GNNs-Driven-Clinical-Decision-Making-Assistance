# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
#     font-family: Inconsolata;
#     font-size: 13px;
# }
#
# div.output_area pre {
#     font-family: Inconsolata;
#     font-size: 11px;
# }
#
# div.text_cell_render {
#     font-family: Inconsolata;
#     font-size: 13px;
# }
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
#     font-family: Inconsolata;
#     font-size: 13px;
# }
#
# div.output_area pre {
#     font-family: Inconsolata;
#     font-size: 11px;
# }
#
# div.text_cell_render {
#     font-family: Inconsolata;
#     font-size: 13px;
# }
# </style>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path_dfs = r"../results/dfs"
list_csvgz = [f for f in os.listdir(path_dfs) if f[-3:]=="csv"]
list_csvgz
# Out:
# ['gnn_type=GATConv_batch_size_by_HADMID=128_auc=0.9910.csv',
#  'gnn_type=GENConv_batch_size_by_HADMID=128_auc=0.9935.csv',
#  'gnn_type=GINEConv_batch_size_by_HADMID=128_auc=0.9691.csv',
#  'gnn_type=GINEConv_batch_size_by_HADMID=128_auc=0.9693.csv',
#  'gnn_type=GINEConv_batch_size_by_HADMID=256_auc=0.9594.csv',
#  'gnn_type=GINEConv_batch_size_by_HADMID=512_auc=0.9394.csv']

# %%
dfs = [pd.read_csv(os.path.join(path_dfs, f)) for f in list_csvgz]
dfs[0]
# Out:
#     Unnamed: 0       auc       acc  f1_marco_avg  f1_weighted_avg  \
# 0            0  0.960526  0.866346      0.639697         0.903862
# 1            1  0.974672  0.897593      0.656539         0.926621
# 2            2  0.982039  0.918203      0.671780         0.941062
# 3            3  0.984609  0.925024      0.666453         0.946729
# 4            4  0.986959  0.934055      0.665165         0.953581
# 5            5  0.989094  0.940776      0.663453         0.958699
# 6            6  0.990476  0.946782      0.660061         0.963302
# 7            7  0.991597  0.951094      0.654482         0.966690
# 8            8  0.993630  0.959684      0.661523         0.972497
# 9            9  0.994488  0.963614      0.659972         0.975332
# 10          10  0.995078  0.966649      0.657420         0.977556
# 11          11  0.995928  0.970577      0.659051         0.980229
# 12          12  0.996198  0.971889      0.653074         0.981337
# 13          13  0.996715  0.973832      0.649784         0.982757
# 14          14  0.997145  0.975149      0.643992         0.983822
# 15          15  0.997387  0.977044      0.642350         0.985157
# 16          16  0.997865  0.979978      0.647605         0.987037
# 17          17  0.998199  0.982253      0.651939         0.988506
# 18          18  0.998294  0.981993      0.639460         0.988549
# 19          19  0.998514  0.983786      0.643737         0.989702
#
#     precision_marco_avg  precision_weighted_avg  recall_marco_avg  \
# 0              0.609128                0.968335          0.901889
# 1              0.614447                0.974867          0.923322
# 2              0.621462                0.978677          0.936058
# 3              0.615603                0.981580          0.942999
# 4              0.612589                0.984288          0.949323
# 5              0.609861                0.986391          0.954924
# 6              0.606218                0.988282          0.958584
# 7              0.601256                0.989783          0.961765
# 8              0.604840                0.991419          0.968802
# 9              0.602860                0.992439          0.971517
# 10             0.600539                0.993275          0.972876
# 11             0.600991                0.994075          0.976019
# 12             0.596540                0.994650          0.976869
# 13             0.593957                0.995187          0.978455
# 14             0.589631                0.995715          0.980596
# 15             0.588308                0.996161          0.980967
# 16             0.591726                0.996614          0.984267
# 17             0.594452                0.996980          0.985907
# 18             0.585729                0.997226          0.985245
# 19             0.590205                0.997510          0.986827
#
#     recall_weighted_avg
# 0              0.866346
# 1              0.897593
# 2              0.918203
# 3              0.925024
# 4              0.934055
# 5              0.940776
# 6              0.946782
# 7              0.951094
# 8              0.959684
# 9              0.963614
# 10             0.966649
# 11             0.970577
# 12             0.971889
# 13             0.973832
# 14             0.975149
# 15             0.977044
# 16             0.979978
# 17             0.982253
# 18             0.981993
# 19             0.983786

# %% [markdown]
# # Different GNN

# %%
total_df_diff_gnn = pd.concat(dfs[:3], keys=["GAT", "GEN", "GIN"])
total_df_diff_gnn.loc['GAT']
# Out:
#     Unnamed: 0       auc       acc  f1_marco_avg  f1_weighted_avg  \
# 0            0  0.960526  0.866346      0.639697         0.903862
# 1            1  0.974672  0.897593      0.656539         0.926621
# 2            2  0.982039  0.918203      0.671780         0.941062
# 3            3  0.984609  0.925024      0.666453         0.946729
# 4            4  0.986959  0.934055      0.665165         0.953581
# 5            5  0.989094  0.940776      0.663453         0.958699
# 6            6  0.990476  0.946782      0.660061         0.963302
# 7            7  0.991597  0.951094      0.654482         0.966690
# 8            8  0.993630  0.959684      0.661523         0.972497
# 9            9  0.994488  0.963614      0.659972         0.975332
# 10          10  0.995078  0.966649      0.657420         0.977556
# 11          11  0.995928  0.970577      0.659051         0.980229
# 12          12  0.996198  0.971889      0.653074         0.981337
# 13          13  0.996715  0.973832      0.649784         0.982757
# 14          14  0.997145  0.975149      0.643992         0.983822
# 15          15  0.997387  0.977044      0.642350         0.985157
# 16          16  0.997865  0.979978      0.647605         0.987037
# 17          17  0.998199  0.982253      0.651939         0.988506
# 18          18  0.998294  0.981993      0.639460         0.988549
# 19          19  0.998514  0.983786      0.643737         0.989702
#
#     precision_marco_avg  precision_weighted_avg  recall_marco_avg  \
# 0              0.609128                0.968335          0.901889
# 1              0.614447                0.974867          0.923322
# 2              0.621462                0.978677          0.936058
# 3              0.615603                0.981580          0.942999
# 4              0.612589                0.984288          0.949323
# 5              0.609861                0.986391          0.954924
# 6              0.606218                0.988282          0.958584
# 7              0.601256                0.989783          0.961765
# 8              0.604840                0.991419          0.968802
# 9              0.602860                0.992439          0.971517
# 10             0.600539                0.993275          0.972876
# 11             0.600991                0.994075          0.976019
# 12             0.596540                0.994650          0.976869
# 13             0.593957                0.995187          0.978455
# 14             0.589631                0.995715          0.980596
# 15             0.588308                0.996161          0.980967
# 16             0.591726                0.996614          0.984267
# 17             0.594452                0.996980          0.985907
# 18             0.585729                0.997226          0.985245
# 19             0.590205                0.997510          0.986827
#
#     recall_weighted_avg
# 0              0.866346
# 1              0.897593
# 2              0.918203
# 3              0.925024
# 4              0.934055
# 5              0.940776
# 6              0.946782
# 7              0.951094
# 8              0.959684
# 9              0.963614
# 10             0.966649
# 11             0.970577
# 12             0.971889
# 13             0.973832
# 14             0.975149
# 15             0.977044
# 16             0.979978
# 17             0.982253
# 18             0.981993
# 19             0.983786

# %%
total_df_diff_gnn.loc['GAT'].auc.mean(), total_df_diff_gnn.loc['GEN'].auc.mean(), total_df_diff_gnn.loc['GIN'].auc.mean()
# Out:
# (0.9909705949072339, 0.9935206256215775, 0.9691451173467278)

# %%
total_df_diff_gnn.loc['GAT'].acc.mean(), total_df_diff_gnn.loc['GEN'].acc.mean(), total_df_diff_gnn.loc['GIN'].acc.mean()
# Out:
# (0.9533160061367433, 0.9607262433241941, 0.9187256879739107)

# %%
total_df_diff_gnn.loc['GAT'].acc.iloc[0], total_df_diff_gnn.loc['GEN'].acc.iloc[0], total_df_diff_gnn.loc['GIN'].acc.iloc[0]
# Out:
# (0.866346027181597, 0.9138890986234278, 0.8726978956932127)

# %%
total_df_diff_gnn.loc['GEN'].recall_marco_avg.mean()
# Out:
# 0.9676839760345481

# %%
total_df_diff_gnn.loc['GEN'].precision_marco_avg.mean(), total_df_diff_gnn.loc['GEN'].precision_weighted_avg.mean()
# Out:
# (0.611030994731014, 0.990099602062139)

# %%
fmts = ('.C7:', '.C5--', '.C2:', '.C3-')
timesteps = range(1, 20+1)

fig, axs = plt.subplots(3, 2, sharex="all", figsize=(3.5*2, 2.5*3))

# precision
axs[0, 0].plot(timesteps, total_df_diff_gnn.loc['GAT'].precision_marco_avg, fmts[1],
               timesteps, total_df_diff_gnn.loc['GEN'].precision_marco_avg, fmts[3],
               timesteps, total_df_diff_gnn.loc['GIN'].precision_marco_avg, fmts[0])
axs[0, 0].set_title('marco average', fontsize=13)
axs[0, 0].set_ylabel('precision', fontsize=13)
axs[0, 0].legend(["GAT", "GEN", "GIN"])
axs[0, 0].grid(True, linestyle='--', linewidth=.57)
axs[0, 1].plot(timesteps, total_df_diff_gnn.loc['GAT'].precision_weighted_avg, fmts[1],
               timesteps, total_df_diff_gnn.loc['GEN'].precision_weighted_avg, fmts[3],
               timesteps, total_df_diff_gnn.loc['GIN'].precision_weighted_avg, fmts[0])
axs[0, 1].set_title('weighted average', fontsize=13)
axs[0, 1].legend(["GAT", "GEN", "GIN"])
axs[0, 1].grid(True, linestyle='--', linewidth=.57)

# recall
axs[1, 0].plot(timesteps, total_df_diff_gnn.loc['GAT'].recall_marco_avg, fmts[1],
               timesteps, total_df_diff_gnn.loc['GEN'].recall_marco_avg, fmts[3],
               timesteps, total_df_diff_gnn.loc['GIN'].recall_marco_avg, fmts[0])
axs[1, 0].set_ylabel('recall', fontsize=13)
axs[1, 0].legend(["GAT", "GEN", "GIN"])
axs[1, 0].grid(True, linestyle='--', linewidth=.57)
axs[1, 1].plot(timesteps, total_df_diff_gnn.loc['GAT'].recall_weighted_avg, fmts[1],
               timesteps, total_df_diff_gnn.loc['GEN'].recall_weighted_avg, fmts[3],
               timesteps, total_df_diff_gnn.loc['GIN'].recall_weighted_avg, fmts[0])
axs[1, 1].legend(["GAT", "GEN", "GIN"])
axs[1, 1].grid(True, linestyle='--', linewidth=.57)

# F1
axs[2, 0].plot(timesteps, total_df_diff_gnn.loc['GAT'].f1_marco_avg, fmts[1],
               timesteps, total_df_diff_gnn.loc['GEN'].f1_marco_avg, fmts[3],
               timesteps, total_df_diff_gnn.loc['GIN'].f1_marco_avg, fmts[0])
axs[2, 0].set_ylabel('F1-score', fontsize=13)
axs[2, 0].set_xlabel('day')
axs[2, 0].legend(["GAT", "GEN", "GIN"])
axs[2, 0].grid(True, linestyle='--', linewidth=.57)
axs[2, 1].plot(timesteps, total_df_diff_gnn.loc['GAT'].f1_weighted_avg, fmts[1],
               timesteps, total_df_diff_gnn.loc['GEN'].f1_weighted_avg, fmts[3],
               timesteps, total_df_diff_gnn.loc['GIN'].f1_weighted_avg, fmts[0])
axs[2, 1].set_xlabel('day')
axs[2, 1].legend(["GAT", "GEN", "GIN"])
axs[2, 1].grid(True, linestyle='--', linewidth=.57)

# fig.suptitle('Performance of different types of GNN per day', fontsize=17)
plt.tight_layout()

# %%
# fmts = ('.k--', 'xm--', 'vg-.', '*r:')
fmts = ('.C7:', '.C5--', '.C2:', '.C3-')
timesteps = np.arange(1, 20+1)

fig, axs = plt.subplots(1, 2, sharex="all", figsize=(3.3*2, 2.5*1))

# AUC
axs[0].plot(timesteps, total_df_diff_gnn.loc['GAT'].auc, fmts[1],
            timesteps, total_df_diff_gnn.loc['GEN'].auc, fmts[3],
            timesteps, total_df_diff_gnn.loc['GIN'].auc, fmts[0])
axs[0].grid(True, linestyle='--', linewidth=.57)
axs[0].set_ylabel('AUC', fontsize=13)
axs[0].set_xlabel('day')
axs[0].legend(["GAT", "GEN", "GIN"])

# ACC
axs[1].plot(timesteps, total_df_diff_gnn.loc['GAT'].acc, fmts[1],
            timesteps, total_df_diff_gnn.loc['GEN'].acc, fmts[3],
            timesteps, total_df_diff_gnn.loc['GIN'].acc, fmts[0])
axs[1].grid(True, linestyle='--', linewidth=.57)
axs[1].set_ylabel('ACC', fontsize=13)
axs[1].set_xlabel('day')
axs[1].legend(["GAT", "GEN", "GIN"])

plt.tight_layout()

# %% [markdown]
# # Differrnt sizes of `batch_size_HADMID`

# %%
total_df_diff_batchsize = pd.concat(dfs[-3:], keys=["128", "256", "512"])
total_df_diff_batchsize.loc['128']
# Out:
#     Unnamed: 0       auc       acc  f1_marco_avg  f1_weighted_avg  \
# 0            0  0.937709  0.876930      0.649301         0.910662
# 1            1  0.951910  0.875625      0.626505         0.912841
# 2            2  0.953315  0.877889      0.615116         0.916174
# 3            3  0.957214  0.881347      0.604238         0.920204
# 4            4  0.960831  0.890272      0.599088         0.927412
# 5            5  0.964738  0.898013      0.595505         0.933463
# 6            6  0.967496  0.903146      0.588419         0.937877
# 7            7  0.969720  0.909115      0.583800         0.942495
# 8            8  0.972645  0.914536      0.579959         0.946722
# 9            9  0.973480  0.915711      0.572484         0.948197
# 10          10  0.976200  0.925075      0.577125         0.954140
# 11          11  0.976677  0.924760      0.569504         0.954601
# 12          12  0.976461  0.926241      0.564470         0.955938
# 13          13  0.977195  0.928830      0.562509         0.957837
# 14          14  0.978536  0.930766      0.558306         0.959372
# 15          15  0.977946  0.931253      0.553006         0.960035
# 16          16  0.978500  0.931209      0.547864         0.960385
# 17          17  0.979112  0.931610      0.544487         0.960910
# 18          18  0.978362  0.934379      0.542187         0.962695
# 19          19  0.977934  0.934668      0.539718         0.963063
#
#     precision_marco_avg  precision_weighted_avg  recall_marco_avg  \
# 0              0.612990                0.968695          0.908188
# 1              0.596205                0.973711          0.912102
# 2              0.587723                0.976767          0.914362
# 3              0.579444                0.979771          0.918415
# 4              0.574287                0.982565          0.922283
# 5              0.570569                0.984783          0.926072
# 6              0.565066                0.986822          0.928352
# 7              0.561153                0.988469          0.929519
# 8              0.557950                0.990137          0.933984
# 9              0.553096                0.991234          0.934543
# 10             0.554578                0.992251          0.937457
# 11             0.550014                0.993096          0.938383
# 12             0.546727                0.993756          0.937636
# 13             0.545232                0.994387          0.938810
# 14             0.542410                0.995032          0.941125
# 15             0.539250                0.995528          0.939881
# 16             0.536228                0.995991          0.941033
# 17             0.534313                0.996401          0.942636
# 18             0.532471                0.996721          0.940952
# 19             0.531160                0.997023          0.940646
#
#     recall_weighted_avg
# 0              0.876930
# 1              0.875625
# 2              0.877889
# 3              0.881347
# 4              0.890272
# 5              0.898013
# 6              0.903146
# 7              0.909115
# 8              0.914536
# 9              0.915711
# 10             0.925075
# 11             0.924760
# 12             0.926241
# 13             0.928830
# 14             0.930766
# 15             0.931253
# 16             0.931209
# 17             0.931610
# 18             0.934379
# 19             0.934668

# %%
fmts = ('k.--', 'xm--', 'vg-.', '*r:')
timesteps = range(1, 20+1)

plt.figure(figsize=(3.5, 2.5))
plt.plot(timesteps, total_df_diff_batchsize.loc['128'].auc, fmts[3],
         timesteps, total_df_diff_batchsize.loc['256'].auc, fmts[1],
         timesteps, total_df_diff_batchsize.loc['512'].auc, fmts[0])
plt.grid(True, linestyle='--', linewidth=.57)

plt.xscale('linear'); plt.xlim((0, max(timesteps)+1)); plt.xlabel("day")
plt.yscale('linear'); plt.ylabel("AUC", fontsize=13); # plt.ylim((0, 1)); 

plt.legend(["128", "256", "512"])
# plt.title("auc of different size of inpatients subset per day")

# %%
fmts = ('k.--', 'xm--', 'vg-.', '*r:')
timesteps = range(1, 20+1)

fig, axs = plt.subplots(3, 2, sharex="all", figsize=(3.5*2, 2.5*3))

# precision
axs[0, 0].plot(timesteps, total_df_diff_batchsize.loc['128'].precision_marco_avg, fmts[1],
               timesteps, total_df_diff_batchsize.loc['256'].precision_marco_avg, fmts[3],
               timesteps, total_df_diff_batchsize.loc['512'].precision_marco_avg, fmts[0])
axs[0, 0].set_title('marco_avg')
axs[0, 0].set_ylabel('precision')
axs[0, 0].legend(["128", "256", "512"])
axs[0, 0].grid(True, linestyle='--', linewidth=.57)
axs[0, 1].plot(timesteps, total_df_diff_batchsize.loc['128'].precision_weighted_avg, fmts[1],
               timesteps, total_df_diff_batchsize.loc['256'].precision_weighted_avg, fmts[3],
               timesteps, total_df_diff_batchsize.loc['512'].precision_weighted_avg, fmts[0])
axs[0, 1].set_title('weighted_avg')
axs[0, 1].legend(["128", "256", "512"])
axs[0, 1].grid(True, linestyle='--', linewidth=.57)

# recall
axs[1, 0].plot(timesteps, total_df_diff_batchsize.loc['128'].recall_marco_avg, fmts[1],
               timesteps, total_df_diff_batchsize.loc['256'].recall_marco_avg, fmts[3],
               timesteps, total_df_diff_batchsize.loc['512'].recall_marco_avg, fmts[0])
axs[1, 0].set_ylabel('recall')
axs[1, 0].legend(["128", "256", "512"])
axs[1, 0].grid(True, linestyle='--', linewidth=.57)
axs[1, 1].plot(timesteps, total_df_diff_batchsize.loc['128'].recall_weighted_avg, fmts[1],
               timesteps, total_df_diff_batchsize.loc['256'].recall_weighted_avg, fmts[3],
               timesteps, total_df_diff_batchsize.loc['512'].recall_weighted_avg, fmts[0])
axs[1, 1].legend(["128", "256", "512"])
axs[1, 1].grid(True, linestyle='--', linewidth=.57)

# F1
axs[2, 0].plot(timesteps, total_df_diff_batchsize.loc['128'].f1_marco_avg, fmts[1],
               timesteps, total_df_diff_batchsize.loc['256'].f1_marco_avg, fmts[3],
               timesteps, total_df_diff_batchsize.loc['512'].f1_marco_avg, fmts[0])
axs[2, 0].set_ylabel('F1-score')
axs[2, 0].set_xlabel('day')
axs[2, 0].legend(["128", "256", "512"])
axs[2, 0].grid(True, linestyle='--', linewidth=.57)
axs[2, 1].plot(timesteps, total_df_diff_batchsize.loc['128'].f1_weighted_avg, fmts[1],
               timesteps, total_df_diff_batchsize.loc['256'].f1_weighted_avg, fmts[3],
               timesteps, total_df_diff_batchsize.loc['512'].f1_weighted_avg, fmts[0])
axs[2, 1].set_xlabel('day')
axs[2, 1].legend(["128", "256", "512"])
axs[2, 1].grid(True, linestyle='--', linewidth=.57)

# fig.suptitle('Performance of different sizes of inpatients subset per day', fontsize=17)
plt.tight_layout()

# %% [markdown]
# # Top50 items

# %%
path_dfs_top50 = r"../results/dfs_top50"
list_csvgz_top50 =  [f for f in os.listdir(path_dfs_top50) if f[-3:]=="csv"]
list_csvgz_top50
# Out:
# ['gnn_type=GENConv_batch_size_by_HADMID=128_auc=0.9936.csv',
#  'top50_items_gnn_type=GENConv_batch_size_by_HADMID=128_auc=0.9602.csv']

# %%
df_total_gen = pd.read_csv(os.path.join(path_dfs_top50, list_csvgz_top50[0]))
df_total_gen
# Out:
#     Unnamed: 0       auc       acc  f1_marco_avg  f1_weighted_avg  \
# 0            0  0.977235  0.912858      0.700450         0.933806
# 1            1  0.984569  0.927823      0.704289         0.945710
# 2            2  0.987405  0.933895      0.700769         0.950885
# 3            3  0.988584  0.939370      0.694917         0.955563
# 4            4  0.990251  0.944987      0.689377         0.960231
# 5            5  0.991522  0.948813      0.682667         0.963527
# 6            6  0.992728  0.952483      0.674116         0.966678
# 7            7  0.993406  0.954999      0.665089         0.968980
# 8            8  0.994946  0.963479      0.674395         0.974720
# 9            9  0.995570  0.965670      0.667673         0.976535
# 10          10  0.995994  0.967785      0.661641         0.978217
# 11          11  0.996614  0.971909      0.664739         0.980994
# 12          12  0.996811  0.972553      0.656594         0.981724
# 13          13  0.997248  0.974944      0.656838         0.983397
# 14          14  0.997685  0.976575      0.652196         0.984621
# 15          15  0.997780  0.977507      0.645360         0.985420
# 16          16  0.998143  0.980826      0.651424         0.987504
# 17          17  0.998367  0.982402      0.651173         0.988581
# 18          18  0.998375  0.982153      0.639697         0.988640
# 19          19  0.998530  0.983660      0.644610         0.989640
#
#     precision_marco_avg  precision_weighted_avg  recall_marco_avg  \
# 0              0.646399                0.971066          0.924216
# 1              0.645713                0.976812          0.938669
# 2              0.641189                0.979816          0.945408
# 3              0.635119                0.982430          0.949274
# 4              0.629339                0.984914          0.954238
# 5              0.623164                0.986794          0.957778
# 6              0.615668                0.988570          0.961805
# 7              0.608364                0.989986          0.964587
# 8              0.614067                0.991605          0.970332
# 9              0.608321                0.992551          0.972928
# 10             0.603456                0.993337          0.974145
# 11             0.604981                0.994136          0.976837
# 12             0.599125                0.994693          0.977790
# 13             0.599346                0.995255          0.979832
# 14             0.595419                0.995773          0.981893
# 15             0.590485                0.996186          0.981690
# 16             0.594236                0.996637          0.984572
# 17             0.593765                0.996976          0.986049
# 18             0.586010                0.997232          0.985625
# 19             0.591183                0.997511          0.986512
#
#     recall_weighted_avg
# 0              0.912858
# 1              0.927823
# 2              0.933895
# 3              0.939370
# 4              0.944987
# 5              0.948813
# 6              0.952483
# 7              0.954999
# 8              0.963479
# 9              0.965670
# 10             0.967785
# 11             0.971909
# 12             0.972553
# 13             0.974944
# 14             0.976575
# 15             0.977507
# 16             0.980826
# 17             0.982402
# 18             0.982153
# 19             0.983660

# %%
df_top50_gen = pd.read_csv(os.path.join(path_dfs_top50, list_csvgz_top50[-1]))
df_top50_gen
# Out:
#     Unnamed: 0       auc       acc  f1_marco_avg  f1_weighted_avg  \
# 0            0  0.857689  0.801466      0.797831         0.799974
# 1            1  0.894079  0.842104      0.834828         0.841728
# 2            2  0.911272  0.851485      0.840094         0.852655
# 3            3  0.922723  0.856033      0.837598         0.859045
# 4            4  0.934938  0.864045      0.836417         0.868787
# 5            5  0.946475  0.876241      0.839451         0.881987
# 6            6  0.955719  0.883242      0.836163         0.890627
# 7            7  0.962755  0.891006      0.833612         0.899383
# 8            8  0.970113  0.900819      0.833854         0.909631
# 9            9  0.974525  0.905940      0.829566         0.915485
# 10          10  0.978491  0.912657      0.828062         0.922397
# 11          11  0.981648  0.918743      0.826027         0.928585
# 12          12  0.984632  0.927280      0.829255         0.936457
# 13          13  0.986591  0.931147      0.825638         0.940362
# 14          14  0.988179  0.939315      0.828141         0.947626
# 15          15  0.989200  0.941270      0.820307         0.949946
# 16          16  0.989914  0.944697      0.815681         0.953391
# 17          17  0.990803  0.947874      0.812215         0.956423
# 18          18  0.991639  0.952039      0.811713         0.960146
# 19          19  0.992292  0.954295      0.809207         0.962405
#
#     precision_marco_avg  precision_weighted_avg  recall_marco_avg  \
# 0              0.806086                0.805364          0.796569
# 1              0.837379                0.842697          0.833722
# 2              0.836341                0.855990          0.846385
# 3              0.827666                0.868072          0.855360
# 4              0.820117                0.883139          0.867136
# 5              0.817318                0.898775          0.880687
# 6              0.807106                0.912222          0.893736
# 7              0.798920                0.923076          0.904324
# 8              0.793496                0.933730          0.916626
# 9              0.784620                0.940868          0.925027
# 10             0.779244                0.947667          0.933378
# 11             0.773535                0.953344          0.940769
# 12             0.774135                0.958983          0.948241
# 13             0.767590                0.962497          0.953138
# 14             0.767416                0.967079          0.958257
# 15             0.757241                0.969665          0.961401
# 16             0.751188                0.972514          0.964324
# 17             0.746404                0.974792          0.966711
# 18             0.744592                0.977265          0.969373
# 19             0.742418                0.979094          0.971021
#
#     recall_weighted_avg
# 0              0.801466
# 1              0.842104
# 2              0.851485
# 3              0.856033
# 4              0.864045
# 5              0.876241
# 6              0.883242
# 7              0.891006
# 8              0.900819
# 9              0.905940
# 10             0.912657
# 11             0.918743
# 12             0.927280
# 13             0.931147
# 14             0.939315
# 15             0.941270
# 16             0.944697
# 17             0.947874
# 18             0.952039
# 19             0.954295

# %%
fmts = ('.C7:', '.C6:', '.C2:', '.C3-')
timesteps = np.arange(1, 20+1)

fig, axs = plt.subplots(1, 2, sharex="all", figsize=(3.3*2, 2.5*1))

# AUC
axs[0].plot(timesteps, df_total_gen.auc, fmts[3],
            timesteps, df_top50_gen.auc, fmts[1])
axs[0].grid(True, linestyle='--', linewidth=.57)
axs[0].set_ylabel('AUC', fontsize=13)
axs[0].set_xlabel('day')
axs[0].legend(["Total", "Top50"])

# ACC
axs[1].plot(timesteps, df_total_gen.acc, fmts[3],
            timesteps, df_top50_gen.acc, fmts[1])
axs[1].grid(True, linestyle='--', linewidth=.57)
axs[1].set_ylabel('ACC', fontsize=13)
axs[1].set_xlabel('day')
axs[1].legend(["Total", "Top50"])

plt.tight_layout()

# %%
fmts = ('.C7:', '.C6:', '.C2:', '.C3-')
timesteps = range(1, 20+1)

fig, axs = plt.subplots(3, 2, sharex="all", figsize=(3.5*2, 2.5*3))

# precision
axs[0, 0].plot(timesteps, df_total_gen.precision_marco_avg, fmts[3],
               timesteps, df_top50_gen.precision_marco_avg, fmts[1])
axs[0, 0].set_title('marco average', fontsize=13)
axs[0, 0].set_ylabel('precision', fontsize=13)
axs[0, 0].legend(["Total", "Top50"])
axs[0, 0].grid(True, linestyle='--', linewidth=.57)
axs[0, 1].plot(timesteps, df_total_gen.precision_weighted_avg, fmts[3],
               timesteps, df_top50_gen.precision_weighted_avg, fmts[1])
axs[0, 1].set_title('weighted average', fontsize=13)
axs[0, 1].legend(["Total", "Top50"])
axs[0, 1].grid(True, linestyle='--', linewidth=.57)

# recall
axs[1, 0].plot(timesteps, df_total_gen.recall_marco_avg, fmts[3],
               timesteps, df_top50_gen.recall_marco_avg, fmts[1])
axs[1, 0].set_ylabel('recall', fontsize=13)
axs[1, 0].legend(["Total", "Top50"])
axs[1, 0].grid(True, linestyle='--', linewidth=.57)
axs[1, 1].plot(timesteps, df_total_gen.recall_weighted_avg, fmts[3],
               timesteps, df_top50_gen.recall_weighted_avg, fmts[1])
axs[1, 1].legend(["Total", "Top50"])
axs[1, 1].grid(True, linestyle='--', linewidth=.57)

# F1
axs[2, 0].plot(timesteps, df_total_gen.f1_marco_avg, fmts[3],
               timesteps, df_top50_gen.f1_marco_avg, fmts[1])
axs[2, 0].set_ylabel('F1-score', fontsize=13)
axs[2, 0].set_xlabel('day')
axs[2, 0].legend(["Total", "Top50"])
axs[2, 0].grid(True, linestyle='--', linewidth=.57)
axs[2, 1].plot(timesteps, df_total_gen.f1_weighted_avg, fmts[3],
               timesteps, df_top50_gen.f1_weighted_avg, fmts[1])
axs[2, 1].set_xlabel('day')
axs[2, 1].legend(["Total", "Top50"])
axs[2, 1].grid(True, linestyle='--', linewidth=.57)

# fig.suptitle('Performance of different types of GNN per day', fontsize=17)
plt.tight_layout()
