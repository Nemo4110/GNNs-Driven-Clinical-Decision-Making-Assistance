# %%
# !pip uninstall -q torchtext pandas-stubs -y

# !pip install -q torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install -q torch_geometric -f https://data.pyg.org/whl/torch-1.12.1+cu113.html
# !pip install -q d2l tqdm scikit-learn dill torcheval Deprecated
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 43.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 47.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 99.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 101.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 105.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 8.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xgboost 2.1.1 requires nvidia-nccl-cu12; platform_system == "Linux" and platform_machine != "aarch64", which is not installed.
# albucore 0.0.13 requires numpy<2,>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.13 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.0.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.

# %% [markdown]
# # Git operations

# %%
# %cd /content/drive/MyDrive/proj/LERS
# Out:
# /content/drive/MyDrive/proj/LERS

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git branch
# Out:
#   adapt-old-backbone-to-one-adm-ond-hg
# * add-baseline-recommenders
#   add-experimental-support-for-different-number-of-used-edge-types
#   add-experimental-support-for-impact-of-different-gnn-layers-number
#   add-experimental-support-for-only-GNN
#   add-global-variable-management
#   add-support-for-changing-the-decoder
#   change-final-predict-head-to-previous-link-predictor
#   change-predictor-and-labels
#   debug-nan-loss-when-train-in-gpu
#   encode-history-days-seq-info
#   fix-padding-and-mask
#   fix-train-one-batch-become-more-and-more-slow-problem
#   master
#   seq-generate-like-nlp
#   support-different-num-of-considered-edge-types
#   target-item-patient-condition-attention-layer

# %%
# !git checkout add-baseline-recommenders
# Out:
# Switched to branch 'add-baseline-recommenders'
# Your branch is up to date with 'origin/add-baseline-recommenders'.

# %%
# !git rev-parse HEAD
# Out:
# b58e2038cfa44045e4dd40f44d2664f75d14490d

# %%
# !git fetch --all
# !git reset --hard origin/add-baseline-recommenders

# %% [markdown]
# # RUN!

# %% [markdown]
# ## Train

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_baseline.py --train --use_gpu --model_name=BPR
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# avg. train loss: 0.5618

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_baseline.py --goal="labitem" --train --use_gpu --model_name=NeuMF
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# avg. train loss: 0.4832

# %% [markdown]
# ## Test

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_baseline.py --test --use_gpu --model_name=NeuMF
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# using saved model: loss_0.5632_NeuMF_goal_drug.pt

# %%
# %cd /content/drive/MyDrive/proj/LERS
# !python run_baseline.py --goal="labitem" --test --use_gpu --model_name=NeuMF --model_ckpt="loss_0.4795_NeuMF_goal_labitem.pt"
# Out:
# /content/drive/MyDrive/proj/LERS
# > loading .csv files...
# > finish loading!
# > total adm whose length > 1: 46725
# > total adm for training: 40883, validating: 1169, testing: 4673
# using saved model: loss_0.4795_NeuMF_goal_labitem.pt
