# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
#     font-family: Inconsolata;
#     font-size: 13px;
# }
#
# div.output_area pre {
#     font-family: Inconsolata;
#     font-size: 13px;
# }
#
# div.text_cell_render {
#     font-family: Inconsolata;
#     font-size: 13px;
# }
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
#     font-family: Inconsolata;
#     font-size: 13px;
# }
#
# div.output_area pre {
#     font-family: Inconsolata;
#     font-size: 13px;
# }
#
# div.text_cell_render {
#     font-family: Inconsolata;
#     font-size: 13px;
# }
# </style>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm, tqdm_notebook
from datetime import datetime, timedelta

# %%
path_dataset = r"/data/data2/041/datasets/mimic-iii-clinical-database-1.4"
list_csvgz = [f for f in os.listdir(path_dataset) if f[-6:]=="csv.gz"]
list_csvgz
# Out:
# ['DRGCODES.csv.gz',
#  'LABEVENTS.csv.gz',
#  'PATIENTS.csv.gz',
#  'D_ITEMS.csv.gz',
#  'DIAGNOSES_ICD.csv.gz',
#  'CAREGIVERS.csv.gz',
#  'SERVICES.csv.gz',
#  'CPTEVENTS.csv.gz',
#  'OUTPUTEVENTS.csv.gz',
#  'D_LABITEMS.csv.gz',
#  'D_ICD_DIAGNOSES.csv.gz',
#  'LABEVENTS_NEW_remove_duplicate_edges.csv.gz',
#  'CALLOUT.csv.gz',
#  'ADMISSIONS.csv.gz',
#  'D_CPT.csv.gz',
#  'INPUTEVENTS_MV.csv.gz',
#  'D_LABITEMS_NEW.csv.gz',
#  'PROCEDUREEVENTS_MV.csv.gz',
#  'ADMISSIONS_NEW.csv.gz',
#  'PRESCRIPTIONS.csv.gz',
#  'NOTEEVENTS.csv.gz',
#  'DATETIMEEVENTS.csv.gz',
#  'MICROBIOLOGYEVENTS.csv.gz',
#  'ICUSTAYS.csv.gz',
#  'D_ICD_PROCEDURES.csv.gz',
#  'LABEVENTS_NEW.csv.gz',
#  'CHARTEVENTS.csv.gz',
#  'TRANSFERS.csv.gz',
#  'PROCEDURES_ICD.csv.gz',
#  'INPUTEVENTS_CV.csv.gz']

# %% [markdown]
# # Prepare necessary `DataFrame`

# %%
df_new_labevents_remove_duplicate_edges = pd.read_csv(os.path.join(path_dataset, "LABEVENTS_NEW_remove_duplicate_edges.csv.gz"))
df_new_labevents_remove_duplicate_edges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15309100 entries, 0 to 15309099
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   Unnamed: 0.1       int64
#  2   ROW_ID             int64
#  3   SUBJECT_ID         int64
#  4   HADM_ID            float64
#  5   ITEMID             int64
#  6   CHARTTIME          object
#  7   VALUE              object
#  8   VALUENUM           float64
#  9   VALUEUOM           object
#  10  FLAG               object
#  11  CATAGORY           float64
#  12  VALUENUM_Z-SCORED  float64
#  13  TIMESTEP           float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 1.6+ GB

# %%
df_d_labitems = pd.read_csv(os.path.join(path_dataset, "D_LABITEMS.csv.gz"))
df_d_labitems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ROW_ID      753 non-null    int64
#  1   ITEMID      753 non-null    int64
#  2   LABEL       753 non-null    object
#  3   FLUID       753 non-null    object
#  4   CATEGORY    753 non-null    object
#  5   LOINC_CODE  585 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 35.4+ KB

# %%
df_prescriptions = pd.read_csv(os.path.join(path_dataset, "PRESCRIPTIONS.csv.gz"))

# Convert columns to datetime
df_prescriptions["ADMITTIME"] = pd.to_datetime(df_prescriptions["STARTDATE"], format="%Y-%m-%d %H:%M:%S")
df_prescriptions["DISCHTIME"] = pd.to_datetime(df_prescriptions["ENDDATE"], format="%Y-%m-%d %H:%M:%S")

df_prescriptions.sort_values(by="STARTDATE", inplace=True)

df_prescriptions.info()
# Out:
# /data/data2/041/envs/LERS2/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3269: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4156450 entries, 1457891 to 4151306
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ROW_ID             int64
#  1   SUBJECT_ID         int64
#  2   HADM_ID            int64
#  3   ICUSTAY_ID         float64
#  4   STARTDATE          object
#  5   ENDDATE            object
#  6   DRUG_TYPE          object
#  7   DRUG               object
#  8   DRUG_NAME_POE      object
#  9   DRUG_NAME_GENERIC  object
#  10  FORMULARY_DRUG_CD  object
#  11  GSN                object
#  12  NDC                float64
#  13  PROD_STRENGTH      object
#  14  DOSE_VAL_RX        object
#  15  DOSE_UNIT_RX       object
#  16  FORM_VAL_DISP      object
#  17  FORM_UNIT_DISP     object
#  18  ROUTE              object
#  19  ADMITTIME          datetime64[ns]
#  20  DISCHTIME          datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(3), object(14)
# memory usage: 697.6+ MB

# %%
df_procedures_icd = pd.read_csv(os.path.join(path_dataset, "PROCEDURES_ICD.csv.gz"))
df_d_icd_procedures = pd.read_csv(os.path.join(path_dataset, "D_ICD_PROCEDURES.csv.gz"))

# %% [markdown]
# # Explore Specific Case

# %%
HADM_ID_temp = 199998

df_temp = df_new_labevents_remove_duplicate_edges[df_new_labevents_remove_duplicate_edges.HADM_ID==HADM_ID_temp].merge(
    df_d_labitems[['ITEMID', 'LABEL']], how='left', on='ITEMID')
df_temp.sort_values(by="TIMESTEP", inplace=True)
df_temp[df_temp.CATAGORY!=0]
# Out:
#      Unnamed: 0  Unnamed: 0.1    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID  \
# 49     21445317      21445317  16833719       27200  199998.0   50920
# 141    21445431      21445431  16833738       27200  199998.0   51464
# 143    21445433      21445433  16833739       27200  199998.0   51466
# 146    21445436      21445436  16833743       27200  199998.0   51487
# 152    21445442      21445442  16833747       27200  199998.0   51506
# 0      21445171      21445171  16833896       27200  199998.0   50800
# 9      21445225      21445225  16833813       27200  199998.0   50812
# 18     21445286      21445286  16833804       27200  199998.0   50828
# 140    21445430      21445430  16833945       27200  199998.0   51464
# 151    21445441      21445441  16833956       27200  199998.0   51506
# 142    21445432      21445432  16833946       27200  199998.0   51466
# 145    21445435      21445435  16833951       27200  199998.0   51487
#
#                CHARTTIME         VALUE  VALUENUM VALUEUOM FLAG  CATAGORY  \
# 49   2119-02-18 17:58:00  See Comments       NaN      NaN  NaN       1.0
# 141  2119-02-18 19:49:00           NEG       NaN    mg/dL  NaN       1.0
# 143  2119-02-18 19:49:00            SM       NaN      NaN  NaN       3.0
# 146  2119-02-18 19:49:00           NEG       NaN      NaN  NaN       1.0
# 152  2119-02-18 19:49:00         Clear       NaN      NaN  NaN       1.0
# 0    2119-02-20 23:10:00           ART       NaN      NaN  NaN       1.0
# 9    2119-02-20 12:59:00     INTUBATED       NaN      NaN  NaN       1.0
# 18   2119-02-20 12:33:00    CONTROLLED       NaN      NaN  NaN       1.0
# 140  2119-02-22 09:32:00           NEG       NaN    mg/dL  NaN       1.0
# 151  2119-02-22 09:32:00         Clear       NaN      NaN  NaN       1.0
# 142  2119-02-22 09:32:00            LG       NaN      NaN  NaN       2.0
# 145  2119-02-22 09:32:00           NEG       NaN      NaN  NaN       1.0
#
#      VALUENUM_Z-SCORED  TIMESTEP                          LABEL
# 49                 0.0       0.0  Estimated GFR (MDRD equation)
# 141                0.0       0.0                      Bilirubin
# 143                0.0       0.0                          Blood
# 146                0.0       0.0                        Nitrite
# 152                0.0       0.0               Urine Appearance
# 0                  0.0       2.0                  SPECIMEN TYPE
# 9                  0.0       2.0                      Intubated
# 18                 0.0       2.0                     Ventilator
# 140                0.0       4.0                      Bilirubin
# 151                0.0       4.0               Urine Appearance
# 142                0.0       4.0                          Blood
# 145                0.0       4.0                        Nitrite

# %%
df_temp[df_temp.CATAGORY==0]
# Out:
#      Unnamed: 0  Unnamed: 0.1    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID  \
# 154    21445444      21445444  16833749       27200  199998.0   51514
# 27     21445295      21445295  16833714       27200  199998.0   50868
# 98     21445374      21445374  16833729       27200  199998.0   51248
# 92     21445366      21445366  16833728       27200  199998.0   51237
# 89     21445362      21445362  16833727       27200  199998.0   51222
# ..          ...           ...       ...         ...       ...     ...
# 72     21445340      21445340  16833986       27200  199998.0   51006
# 44     21445312      21445312  16833982       27200  199998.0   50912
# 129    21445416      21445416  16834005       27200  199998.0   51279
# 51     21445319      21445319  16833983       27200  199998.0   50931
# 85     21445357      21445357  16833997       27200  199998.0   51222
#
#                CHARTTIME VALUE  VALUENUM VALUEUOM      FLAG  CATAGORY  \
# 154  2119-02-18 19:49:00     4      4.00    mg/dL  abnormal       0.0
# 27   2119-02-18 17:58:00    15     15.00    mEq/L       NaN       0.0
# 98   2119-02-18 17:58:00  33.0     33.00       pg  abnormal       0.0
# 92   2119-02-18 17:58:00   1.0      1.00      NaN       NaN       0.0
# 89   2119-02-18 17:58:00  12.8     12.80     g/dL  abnormal       0.0
# ..                   ...   ...       ...      ...       ...       ...
# 72   2119-02-24 04:00:00    25     25.00    mg/dL  abnormal       0.0
# 44   2119-02-24 04:00:00   1.1      1.10    mg/dL       NaN       0.0
# 129  2119-02-24 08:15:00  3.04      3.04     m/uL  abnormal       0.0
# 51   2119-02-24 04:00:00   112    112.00    mg/dL  abnormal       0.0
# 85   2119-02-24 08:15:00   9.8      9.80     g/dL  abnormal       0.0
#
#      VALUENUM_Z-SCORED  TIMESTEP            LABEL
# 154           8.935176       0.0     Urobilinogen
# 27            0.578508       0.0        Anion Gap
# 98            2.480894       0.0              MCH
# 92           -0.641693       0.0          INR(PT)
# 89           -0.670068       0.0       Hemoglobin
# ..                 ...       ...              ...
# 72            2.870949       6.0    Urea Nitrogen
# 44            1.389148       6.0       Creatinine
# 129          -4.377918       6.0  Red Blood Cells
# 51            2.322528       6.0          Glucose
# 85           -3.029526       6.0       Hemoglobin
#
# [143 rows x 15 columns]

# %%
df_temp[df_temp.CATAGORY!=0]
# Out:
#      Unnamed: 0  Unnamed: 0.1    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID  \
# 49     21445317      21445317  16833719       27200  199998.0   50920
# 141    21445431      21445431  16833738       27200  199998.0   51464
# 143    21445433      21445433  16833739       27200  199998.0   51466
# 146    21445436      21445436  16833743       27200  199998.0   51487
# 152    21445442      21445442  16833747       27200  199998.0   51506
# 0      21445171      21445171  16833896       27200  199998.0   50800
# 9      21445225      21445225  16833813       27200  199998.0   50812
# 18     21445286      21445286  16833804       27200  199998.0   50828
# 140    21445430      21445430  16833945       27200  199998.0   51464
# 151    21445441      21445441  16833956       27200  199998.0   51506
# 142    21445432      21445432  16833946       27200  199998.0   51466
# 145    21445435      21445435  16833951       27200  199998.0   51487
#
#                CHARTTIME         VALUE  VALUENUM VALUEUOM FLAG  CATAGORY  \
# 49   2119-02-18 17:58:00  See Comments       NaN      NaN  NaN       1.0
# 141  2119-02-18 19:49:00           NEG       NaN    mg/dL  NaN       1.0
# 143  2119-02-18 19:49:00            SM       NaN      NaN  NaN       3.0
# 146  2119-02-18 19:49:00           NEG       NaN      NaN  NaN       1.0
# 152  2119-02-18 19:49:00         Clear       NaN      NaN  NaN       1.0
# 0    2119-02-20 23:10:00           ART       NaN      NaN  NaN       1.0
# 9    2119-02-20 12:59:00     INTUBATED       NaN      NaN  NaN       1.0
# 18   2119-02-20 12:33:00    CONTROLLED       NaN      NaN  NaN       1.0
# 140  2119-02-22 09:32:00           NEG       NaN    mg/dL  NaN       1.0
# 151  2119-02-22 09:32:00         Clear       NaN      NaN  NaN       1.0
# 142  2119-02-22 09:32:00            LG       NaN      NaN  NaN       2.0
# 145  2119-02-22 09:32:00           NEG       NaN      NaN  NaN       1.0
#
#      VALUENUM_Z-SCORED  TIMESTEP                          LABEL
# 49                 0.0       0.0  Estimated GFR (MDRD equation)
# 141                0.0       0.0                      Bilirubin
# 143                0.0       0.0                          Blood
# 146                0.0       0.0                        Nitrite
# 152                0.0       0.0               Urine Appearance
# 0                  0.0       2.0                  SPECIMEN TYPE
# 9                  0.0       2.0                      Intubated
# 18                 0.0       2.0                     Ventilator
# 140                0.0       4.0                      Bilirubin
# 151                0.0       4.0               Urine Appearance
# 142                0.0       4.0                          Blood
# 145                0.0       4.0                        Nitrite

# %%
df_temp[df_temp.TIMESTEP==0]
# Out:
#      Unnamed: 0  Unnamed: 0.1    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID  \
# 154    21445444      21445444  16833749       27200  199998.0   51514
# 27     21445295      21445295  16833714       27200  199998.0   50868
# 98     21445374      21445374  16833729       27200  199998.0   51248
# 92     21445366      21445366  16833728       27200  199998.0   51237
# 89     21445362      21445362  16833727       27200  199998.0   51222
# 34     21445302      21445302  16833715       27200  199998.0   50882
# 36     21445304      21445304  16833716       27200  199998.0   50893
# 49     21445317      21445317  16833719       27200  199998.0   50920
# 83     21445354      21445354  16833726       27200  199998.0   51221
# 42     21445310      21445310  16833717       27200  199998.0   50902
# 70     21445338      21445338  16833724       27200  199998.0   50983
# 65     21445333      21445333  16833723       27200  199998.0   50971
# 60     21445328      21445328  16833722       27200  199998.0   50970
# 59     21445327      21445327  16833721       27200  199998.0   50960
# 48     21445316      21445316  16833718       27200  199998.0   50912
# 76     21445344      21445344  16833725       27200  199998.0   51006
# 110    21445390      21445390  16833731       27200  199998.0   51250
# 104    21445382      21445382  16833730       27200  199998.0   51249
# 54     21445322      21445322  16833720       27200  199998.0   50931
# 133    21445421      21445421  16833736       27200  199998.0   51279
# 116    21445398      21445398  16833732       27200  199998.0   51265
# 127    21445413      21445413  16833735       27200  199998.0   51277
# 141    21445431      21445431  16833738       27200  199998.0   51464
# 143    21445433      21445433  16833739       27200  199998.0   51466
# 146    21445436      21445436  16833743       27200  199998.0   51487
# 121    21445405      21445405  16833734       27200  199998.0   51275
# 148    21445438      21445438  16833744       27200  199998.0   51491
# 139    21445429      21445429  16833737       27200  199998.0   51301
# 119    21445402      21445402  16833733       27200  199998.0   51274
# 152    21445442      21445442  16833747       27200  199998.0   51506
# 150    21445440      21445440  16833746       27200  199998.0   51498
#
#                CHARTTIME         VALUE  VALUENUM VALUEUOM      FLAG  CATAGORY  \
# 154  2119-02-18 19:49:00             4      4.00    mg/dL  abnormal       0.0
# 27   2119-02-18 17:58:00            15     15.00    mEq/L       NaN       0.0
# 98   2119-02-18 17:58:00          33.0     33.00       pg  abnormal       0.0
# 92   2119-02-18 17:58:00           1.0      1.00      NaN       NaN       0.0
# 89   2119-02-18 17:58:00          12.8     12.80     g/dL  abnormal       0.0
# 34   2119-02-18 17:58:00            27     27.00    mEq/L       NaN       0.0
# 36   2119-02-18 17:58:00          10.2     10.20    mg/dL       NaN       0.0
# 49   2119-02-18 17:58:00  See Comments       NaN      NaN       NaN       1.0
# 83   2119-02-18 17:58:00          37.0     37.00        %  abnormal       0.0
# 42   2119-02-18 17:58:00           103    103.00    mEq/L       NaN       0.0
# 70   2119-02-18 17:58:00           141    141.00    mEq/L       NaN       0.0
# 65   2119-02-18 17:58:00           4.3      4.30    mEq/L       NaN       0.0
# 60   2119-02-18 17:58:00           3.6      3.60    mg/dL       NaN       0.0
# 59   2119-02-18 17:58:00           1.7      1.70    mg/dL       NaN       0.0
# 48   2119-02-18 17:58:00           0.9      0.90    mg/dL       NaN       0.0
# 76   2119-02-18 17:58:00            16     16.00    mg/dL       NaN       0.0
# 110  2119-02-18 17:58:00            95     95.00       fL       NaN       0.0
# 104  2119-02-18 17:58:00          34.7     34.70        %       NaN       0.0
# 54   2119-02-18 17:58:00           109    109.00    mg/dL  abnormal       0.0
# 133  2119-02-18 17:58:00          3.89      3.89     m/uL  abnormal       0.0
# 116  2119-02-18 17:58:00           241    241.00     K/uL       NaN       0.0
# 127  2119-02-18 17:58:00          13.7     13.70        %       NaN       0.0
# 141  2119-02-18 19:49:00           NEG       NaN    mg/dL       NaN       1.0
# 143  2119-02-18 19:49:00            SM       NaN      NaN       NaN       3.0
# 146  2119-02-18 19:49:00           NEG       NaN      NaN       NaN       1.0
# 121  2119-02-18 17:58:00          29.0     29.00      sec       NaN       0.0
# 148  2119-02-18 19:49:00           6.5      6.50    units       NaN       0.0
# 139  2119-02-18 17:58:00           9.6      9.60     K/uL       NaN       0.0
# 119  2119-02-18 17:58:00          11.7     11.70      sec       NaN       0.0
# 152  2119-02-18 19:49:00         Clear       NaN      NaN       NaN       1.0
# 150  2119-02-18 19:49:00         1.010      1.01                NaN       0.0
#
#      VALUENUM_Z-SCORED  TIMESTEP                          LABEL
# 154           8.935176       0.0                   Urobilinogen
# 27            0.578508       0.0                      Anion Gap
# 98            2.480894       0.0                            MCH
# 92           -0.641693       0.0                        INR(PT)
# 89           -0.670068       0.0                     Hemoglobin
# 34            0.377594       0.0                    Bicarbonate
# 36            2.954342       0.0                 Calcium, Total
# 49            0.000000       0.0  Estimated GFR (MDRD equation)
# 83           -1.114777       0.0                     Hematocrit
# 42            0.019351       0.0                       Chloride
# 70            0.658737       0.0                         Sodium
# 65            0.500345       0.0                      Potassium
# 60            0.221017       0.0                      Phosphate
# 59           -1.347833       0.0                      Magnesium
# 48            0.489554       0.0                     Creatinine
# 76            0.603423       0.0                  Urea Nitrogen
# 110           1.305191       0.0                            MCV
# 104           1.350207       0.0                           MCHC
# 54            1.983991       0.0                        Glucose
# 133          -2.099357       0.0                Red Blood Cells
# 116          -0.219176       0.0                 Platelet Count
# 127          -0.478243       0.0                            RDW
# 141           0.000000       0.0                      Bilirubin
# 143           0.000000       0.0                          Blood
# 146           0.000000       0.0                        Nitrite
# 121           0.073793       0.0                            PTT
# 148           0.707835       0.0                             pH
# 139           0.911509       0.0              White Blood Cells
# 119          -1.369342       0.0                             PT
# 152           0.000000       0.0               Urine Appearance
# 150          -0.808338       0.0               Specific Gravity

# %%
df_prescriptions[df_prescriptions.HADM_ID==HADM_ID_temp]
# Out:
#           ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 1961425  3189028       27200   199998         NaN  2119-02-18 00:00:00
# 1961433  3189027       27200   199998         NaN  2119-02-18 00:00:00
# 1961427  3189033       27200   199998         NaN  2119-02-18 00:00:00
# 1961432  3189026       27200   199998         NaN  2119-02-18 00:00:00
# 1961431  3189025       27200   199998         NaN  2119-02-18 00:00:00
# ...          ...         ...      ...         ...                  ...
# 1958140  3190291       27200   199998         NaN  2119-02-23 00:00:00
# 1958141  3190293       27200   199998         NaN  2119-02-23 00:00:00
# 1958142  3190292       27200   199998         NaN  2119-02-23 00:00:00
# 1958143  3190294       27200   199998         NaN  2119-02-23 00:00:00
# 1958144  3190295       27200   199998         NaN  2119-02-24 00:00:00
#
#                      ENDDATE DRUG_TYPE                         DRUG  \
# 1961425  2119-02-18 00:00:00      MAIN          Hydrochlorothiazide
# 1961433  2119-02-20 00:00:00      MAIN                    Doxazosin
# 1961427  2119-02-20 00:00:00      MAIN             Nitroglycerin SL
# 1961432  2119-02-20 00:00:00      MAIN                   Aspirin EC
# 1961431  2119-02-20 00:00:00      MAIN  Sodium Chloride 0.9%  Flush
# ...                      ...       ...                          ...
# 1958140  2119-02-23 00:00:00      MAIN          Metoprolol Tartrate
# 1958141  2119-02-24 00:00:00      MAIN                     Warfarin
# 1958142  2119-02-24 00:00:00      MAIN                     Warfarin
# 1958143  2119-02-24 00:00:00      MAIN          Metoprolol Tartrate
# 1958144  2119-02-24 00:00:00      MAIN           Potassium Chloride
#
#                        DRUG_NAME_POE            DRUG_NAME_GENERIC  ...  \
# 1961425          Hydrochlorothiazide          Hydrochlorothiazide  ...
# 1961433                    Doxazosin                    Doxazosin  ...
# 1961427             Nitroglycerin SL             Nitroglycerin SL  ...
# 1961432                   Aspirin EC                   Aspirin EC  ...
# 1961431  Sodium Chloride 0.9%  Flush  Sodium Chloride 0.9%  Flush  ...
# ...                              ...                          ...  ...
# 1958140          Metoprolol Tartrate          Metoprolol Tartrate  ...
# 1958141                     Warfarin                     Warfarin  ...
# 1958142                     Warfarin                     Warfarin  ...
# 1958143          Metoprolol Tartrate          Metoprolol Tartrate  ...
# 1958144           Potassium Chloride           Potassium Chloride  ...
#
#             GSN           NDC           PROD_STRENGTH DOSE_VAL_RX  \
# 1961425  029832  6.033855e+08             25mg Tablet          25
# 1961433  015584  9.045523e+08              1mg Tablet           1
# 1961427  000474  5.817703e+10  0.3mg SL Tablet Bottle         0.3
# 1961432  004381  1.771400e+10               325mg Tab         325
# 1961431     NaN  0.000000e+00                 Syringe           3
# ...         ...           ...                     ...         ...
# 1958140  005132  5.107908e+10             50mg Tablet          50
# 1958141  014198  5.601698e+07  Check with MD for Dose           1
# 1958142  014198  5.601698e+07              1mg Tablet           3
# 1958143  050631  5.107903e+10             25mg Tablet          75
# 1958144  022346  5.817702e+10        20 mEq SR Tablet          20
#
#         DOSE_UNIT_RX FORM_VAL_DISP FORM_UNIT_DISP ROUTE  ADMITTIME  DISCHTIME
# 1961425           mg             1            TAB    PO 2119-02-18 2119-02-18
# 1961433           mg             1            TAB    PO 2119-02-18 2119-02-20
# 1961427           mg             1            TAB    SL 2119-02-18 2119-02-20
# 1961432           mg             1            TAB    PO 2119-02-18 2119-02-20
# 1961431           mL           0.6            SYR    IV 2119-02-18 2119-02-20
# ...              ...           ...            ...   ...        ...        ...
# 1958140           mg             1            TAB    PO 2119-02-23 2119-02-23
# 1958141         dose             1           dose    PO 2119-02-23 2119-02-24
# 1958142           mg             3            TAB    PO 2119-02-23 2119-02-24
# 1958143           mg             3            TAB    PO 2119-02-23 2119-02-24
# 1958144          mEq             1            TAB    PO 2119-02-24 2119-02-24
#
# [104 rows x 21 columns]

# %%
df_procedures_icd[df_procedures_icd.HADM_ID==HADM_ID_temp].merge(df_d_icd_procedures[["ICD9_CODE", "LONG_TITLE"]], how="left", on="ICD9_CODE")
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0  157105       27200   199998        1       3612
# 1  157106       27200   199998        2       3615
# 2  157107       27200   199998        3       3964
#
#                                         LONG_TITLE
# 0  (Aorto)coronary bypass of two coronary arteries
# 1   Single internal mammary-coronary artery bypass
# 2                 Intraoperative cardiac pacemaker
