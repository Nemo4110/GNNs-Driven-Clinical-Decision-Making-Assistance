# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
#     font-family: Inconsolata;
#     font-size: 13px;
# }
#
# div.output_area pre {
#     font-family: Inconsolata;
#     font-size: 11px;
# }
#
# div.text_cell_render {
#     font-family: Inconsolata;
#     font-size: 15px;
# }
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
#     font-family: Inconsolata;
#     font-size: 13px;
# }
#
# div.output_area pre {
#     font-family: Inconsolata;
#     font-size: 11px;
# }
#
# div.text_cell_render {
#     font-family: Inconsolata;
#     font-size: 15px;
# }
# </style>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm, tqdm_notebook
from datetime import datetime, timedelta

# %%
path_dataset = r"/data/data2/041/datasets/mimic-iii-clinical-database-1.4"
list_csvgz = [f for f in os.listdir(path_dataset) if f[-6:]=="csv.gz"]
list_csvgz
# Out:
# ['DRGCODES.csv.gz',
#  'LABEVENTS.csv.gz',
#  'PATIENTS.csv.gz',
#  'D_ITEMS.csv.gz',
#  'DIAGNOSES_ICD.csv.gz',
#  'CAREGIVERS.csv.gz',
#  'SERVICES.csv.gz',
#  'CPTEVENTS.csv.gz',
#  'PRESCRIPTIONS_PREPROCESSED.csv.gz',
#  'OUTPUTEVENTS.csv.gz',
#  'D_LABITEMS.csv.gz',
#  'D_ICD_DIAGNOSES.csv.gz',
#  'CALLOUT.csv.gz',
#  'ADMISSIONS.csv.gz',
#  'D_CPT.csv.gz',
#  'INPUTEVENTS_MV.csv.gz',
#  'D_LABITEMS_NEW.csv.gz',
#  'PROCEDUREEVENTS_MV.csv.gz',
#  'ADMISSIONS_NEW.csv.gz',
#  'PRESCRIPTIONS.csv.gz',
#  'NOTEEVENTS.csv.gz',
#  'DATETIMEEVENTS.csv.gz',
#  'MICROBIOLOGYEVENTS.csv.gz',
#  'ICUSTAYS.csv.gz',
#  'DRUGS_NDC_FEAT.csv.gz',
#  'D_ICD_PROCEDURES.csv.gz',
#  'CHARTEVENTS.csv.gz',
#  'TRANSFERS.csv.gz',
#  'PROCEDURES_ICD.csv.gz',
#  'LABEVENTS_PREPROCESSED.csv.gz',
#  'INPUTEVENTS_CV.csv.gz']

# %% [markdown]
# # Prepare necessary `DataFrame`

# %%
df_labevents = pd.read_csv(os.path.join(path_dataset, "LABEVENTS_PREPROCESSED.csv.gz"))
df_labevents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15186986 entries, 0 to 15186985
# Data columns (total 13 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   ROW_ID             int64
#  2   SUBJECT_ID         int64
#  3   HADM_ID            float64
#  4   ITEMID             int64
#  5   CHARTTIME          object
#  6   VALUE              object
#  7   VALUENUM           float64
#  8   VALUEUOM           object
#  9   FLAG               object
#  10  CATAGORY           float64
#  11  VALUENUM_Z-SCORED  float64
#  12  TIMESTEP           float64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 1.5+ GB

# %%
df_d_labitems = pd.read_csv(os.path.join(path_dataset, "D_LABITEMS.csv.gz"))
df_d_labitems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ROW_ID      753 non-null    int64
#  1   ITEMID      753 non-null    int64
#  2   LABEL       753 non-null    object
#  3   FLUID       753 non-null    object
#  4   CATEGORY    753 non-null    object
#  5   LOINC_CODE  585 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 35.4+ KB

# %%
# df_prescriptions = pd.read_csv(os.path.join(path_dataset, "PRESCRIPTIONS_PREPROCESSED.csv.gz"))
df_prescriptions = pd.read_csv(os.path.join(path_dataset, "PRESCRIPTIONS.csv.gz"))

# Convert columns to datetime
df_prescriptions["STARTDATE"] = pd.to_datetime(df_prescriptions["STARTDATE"], format="%Y-%m-%d %H:%M:%S")
df_prescriptions["ENDDATE"] = pd.to_datetime(df_prescriptions["ENDDATE"], format="%Y-%m-%d %H:%M:%S")

df_prescriptions.sort_values(by="STARTDATE", inplace=True)

df_prescriptions.info()
# Out:
# /data/data2/041/envs/LERS2/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3269: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4156450 entries, 1457891 to 4151306
# Data columns (total 19 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ROW_ID             int64
#  1   SUBJECT_ID         int64
#  2   HADM_ID            int64
#  3   ICUSTAY_ID         float64
#  4   STARTDATE          datetime64[ns]
#  5   ENDDATE            datetime64[ns]
#  6   DRUG_TYPE          object
#  7   DRUG               object
#  8   DRUG_NAME_POE      object
#  9   DRUG_NAME_GENERIC  object
#  10  FORMULARY_DRUG_CD  object
#  11  GSN                object
#  12  NDC                float64
#  13  PROD_STRENGTH      object
#  14  DOSE_VAL_RX        object
#  15  DOSE_UNIT_RX       object
#  16  FORM_VAL_DISP      object
#  17  FORM_UNIT_DISP     object
#  18  ROUTE              object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(12)
# memory usage: 634.2+ MB

# %%
df_procedures_icd = pd.read_csv(os.path.join(path_dataset, "PROCEDURES_ICD.csv.gz"))
df_d_icd_procedures = pd.read_csv(os.path.join(path_dataset, "D_ICD_PROCEDURES.csv.gz"))

# %% [markdown]
# # Explore Specific Case

# %%
HADM_ID_temp = 199998

df_temp = df_labevents[df_labevents.HADM_ID==HADM_ID_temp].merge(
    df_d_labitems[['ITEMID', 'LABEL']], how='left', on='ITEMID')
df_temp.sort_values(by="TIMESTEP", inplace=True)
df_temp[df_temp.CATAGORY!=0]
# Out:
#      Unnamed: 0    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME  \
# 49     21445317  16833719       27200  199998.0   50920  2119-02-18 17:58:00
# 141    21445431  16833738       27200  199998.0   51464  2119-02-18 19:49:00
# 143    21445433  16833739       27200  199998.0   51466  2119-02-18 19:49:00
# 146    21445436  16833743       27200  199998.0   51487  2119-02-18 19:49:00
# 152    21445442  16833747       27200  199998.0   51506  2119-02-18 19:49:00
# 0      21445171  16833896       27200  199998.0   50800  2119-02-20 23:10:00
# 9      21445225  16833813       27200  199998.0   50812  2119-02-20 12:59:00
# 18     21445286  16833804       27200  199998.0   50828  2119-02-20 12:33:00
# 140    21445430  16833945       27200  199998.0   51464  2119-02-22 09:32:00
# 151    21445441  16833956       27200  199998.0   51506  2119-02-22 09:32:00
# 142    21445432  16833946       27200  199998.0   51466  2119-02-22 09:32:00
# 145    21445435  16833951       27200  199998.0   51487  2119-02-22 09:32:00
#
#             VALUE  VALUENUM VALUEUOM FLAG  CATAGORY  VALUENUM_Z-SCORED  \
# 49   See Comments       NaN      NaN  NaN       1.0                0.0
# 141           NEG       NaN    mg/dL  NaN       1.0                0.0
# 143            SM       NaN      NaN  NaN       3.0                0.0
# 146           NEG       NaN      NaN  NaN       1.0                0.0
# 152         Clear       NaN      NaN  NaN       1.0                0.0
# 0             ART       NaN      NaN  NaN       1.0                0.0
# 9       INTUBATED       NaN      NaN  NaN       1.0                0.0
# 18     CONTROLLED       NaN      NaN  NaN       1.0                0.0
# 140           NEG       NaN    mg/dL  NaN       1.0                0.0
# 151         Clear       NaN      NaN  NaN       1.0                0.0
# 142            LG       NaN      NaN  NaN       2.0                0.0
# 145           NEG       NaN      NaN  NaN       1.0                0.0
#
#      TIMESTEP                          LABEL
# 49        0.0  Estimated GFR (MDRD equation)
# 141       0.0                      Bilirubin
# 143       0.0                          Blood
# 146       0.0                        Nitrite
# 152       0.0               Urine Appearance
# 0         2.0                  SPECIMEN TYPE
# 9         2.0                      Intubated
# 18        2.0                     Ventilator
# 140       4.0                      Bilirubin
# 151       4.0               Urine Appearance
# 142       4.0                          Blood
# 145       4.0                        Nitrite

# %%
df_temp[df_temp.CATAGORY==0]
# Out:
#      Unnamed: 0    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME  \
# 154    21445444  16833749       27200  199998.0   51514  2119-02-18 19:49:00
# 27     21445295  16833714       27200  199998.0   50868  2119-02-18 17:58:00
# 98     21445374  16833729       27200  199998.0   51248  2119-02-18 17:58:00
# 92     21445366  16833728       27200  199998.0   51237  2119-02-18 17:58:00
# 89     21445362  16833727       27200  199998.0   51222  2119-02-18 17:58:00
# ..          ...       ...         ...       ...     ...                  ...
# 72     21445340  16833986       27200  199998.0   51006  2119-02-24 04:00:00
# 44     21445312  16833982       27200  199998.0   50912  2119-02-24 04:00:00
# 129    21445416  16834005       27200  199998.0   51279  2119-02-24 08:15:00
# 51     21445319  16833983       27200  199998.0   50931  2119-02-24 04:00:00
# 85     21445357  16833997       27200  199998.0   51222  2119-02-24 08:15:00
#
#     VALUE  VALUENUM VALUEUOM      FLAG  CATAGORY  VALUENUM_Z-SCORED  TIMESTEP  \
# 154     4      4.00    mg/dL  abnormal       0.0           8.935176       0.0
# 27     15     15.00    mEq/L       NaN       0.0           0.578508       0.0
# 98   33.0     33.00       pg  abnormal       0.0           2.480894       0.0
# 92    1.0      1.00      NaN       NaN       0.0          -0.641693       0.0
# 89   12.8     12.80     g/dL  abnormal       0.0          -0.670068       0.0
# ..    ...       ...      ...       ...       ...                ...       ...
# 72     25     25.00    mg/dL  abnormal       0.0           2.870949       6.0
# 44    1.1      1.10    mg/dL       NaN       0.0           1.389148       6.0
# 129  3.04      3.04     m/uL  abnormal       0.0          -4.377918       6.0
# 51    112    112.00    mg/dL  abnormal       0.0           2.322528       6.0
# 85    9.8      9.80     g/dL  abnormal       0.0          -3.029526       6.0
#
#                LABEL
# 154     Urobilinogen
# 27         Anion Gap
# 98               MCH
# 92           INR(PT)
# 89        Hemoglobin
# ..               ...
# 72     Urea Nitrogen
# 44        Creatinine
# 129  Red Blood Cells
# 51           Glucose
# 85        Hemoglobin
#
# [143 rows x 14 columns]

# %%
df_temp[df_temp.CATAGORY!=0]
# Out:
#      Unnamed: 0    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME  \
# 49     21445317  16833719       27200  199998.0   50920  2119-02-18 17:58:00
# 141    21445431  16833738       27200  199998.0   51464  2119-02-18 19:49:00
# 143    21445433  16833739       27200  199998.0   51466  2119-02-18 19:49:00
# 146    21445436  16833743       27200  199998.0   51487  2119-02-18 19:49:00
# 152    21445442  16833747       27200  199998.0   51506  2119-02-18 19:49:00
# 0      21445171  16833896       27200  199998.0   50800  2119-02-20 23:10:00
# 9      21445225  16833813       27200  199998.0   50812  2119-02-20 12:59:00
# 18     21445286  16833804       27200  199998.0   50828  2119-02-20 12:33:00
# 140    21445430  16833945       27200  199998.0   51464  2119-02-22 09:32:00
# 151    21445441  16833956       27200  199998.0   51506  2119-02-22 09:32:00
# 142    21445432  16833946       27200  199998.0   51466  2119-02-22 09:32:00
# 145    21445435  16833951       27200  199998.0   51487  2119-02-22 09:32:00
#
#             VALUE  VALUENUM VALUEUOM FLAG  CATAGORY  VALUENUM_Z-SCORED  \
# 49   See Comments       NaN      NaN  NaN       1.0                0.0
# 141           NEG       NaN    mg/dL  NaN       1.0                0.0
# 143            SM       NaN      NaN  NaN       3.0                0.0
# 146           NEG       NaN      NaN  NaN       1.0                0.0
# 152         Clear       NaN      NaN  NaN       1.0                0.0
# 0             ART       NaN      NaN  NaN       1.0                0.0
# 9       INTUBATED       NaN      NaN  NaN       1.0                0.0
# 18     CONTROLLED       NaN      NaN  NaN       1.0                0.0
# 140           NEG       NaN    mg/dL  NaN       1.0                0.0
# 151         Clear       NaN      NaN  NaN       1.0                0.0
# 142            LG       NaN      NaN  NaN       2.0                0.0
# 145           NEG       NaN      NaN  NaN       1.0                0.0
#
#      TIMESTEP                          LABEL
# 49        0.0  Estimated GFR (MDRD equation)
# 141       0.0                      Bilirubin
# 143       0.0                          Blood
# 146       0.0                        Nitrite
# 152       0.0               Urine Appearance
# 0         2.0                  SPECIMEN TYPE
# 9         2.0                      Intubated
# 18        2.0                     Ventilator
# 140       4.0                      Bilirubin
# 151       4.0               Urine Appearance
# 142       4.0                          Blood
# 145       4.0                        Nitrite

# %%
df_temp[df_temp.TIMESTEP==0]
# Out:
#      Unnamed: 0    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME  \
# 154    21445444  16833749       27200  199998.0   51514  2119-02-18 19:49:00
# 27     21445295  16833714       27200  199998.0   50868  2119-02-18 17:58:00
# 98     21445374  16833729       27200  199998.0   51248  2119-02-18 17:58:00
# 92     21445366  16833728       27200  199998.0   51237  2119-02-18 17:58:00
# 89     21445362  16833727       27200  199998.0   51222  2119-02-18 17:58:00
# 34     21445302  16833715       27200  199998.0   50882  2119-02-18 17:58:00
# 36     21445304  16833716       27200  199998.0   50893  2119-02-18 17:58:00
# 49     21445317  16833719       27200  199998.0   50920  2119-02-18 17:58:00
# 83     21445354  16833726       27200  199998.0   51221  2119-02-18 17:58:00
# 42     21445310  16833717       27200  199998.0   50902  2119-02-18 17:58:00
# 70     21445338  16833724       27200  199998.0   50983  2119-02-18 17:58:00
# 65     21445333  16833723       27200  199998.0   50971  2119-02-18 17:58:00
# 60     21445328  16833722       27200  199998.0   50970  2119-02-18 17:58:00
# 59     21445327  16833721       27200  199998.0   50960  2119-02-18 17:58:00
# 48     21445316  16833718       27200  199998.0   50912  2119-02-18 17:58:00
# 76     21445344  16833725       27200  199998.0   51006  2119-02-18 17:58:00
# 110    21445390  16833731       27200  199998.0   51250  2119-02-18 17:58:00
# 104    21445382  16833730       27200  199998.0   51249  2119-02-18 17:58:00
# 54     21445322  16833720       27200  199998.0   50931  2119-02-18 17:58:00
# 133    21445421  16833736       27200  199998.0   51279  2119-02-18 17:58:00
# 116    21445398  16833732       27200  199998.0   51265  2119-02-18 17:58:00
# 127    21445413  16833735       27200  199998.0   51277  2119-02-18 17:58:00
# 141    21445431  16833738       27200  199998.0   51464  2119-02-18 19:49:00
# 143    21445433  16833739       27200  199998.0   51466  2119-02-18 19:49:00
# 146    21445436  16833743       27200  199998.0   51487  2119-02-18 19:49:00
# 121    21445405  16833734       27200  199998.0   51275  2119-02-18 17:58:00
# 148    21445438  16833744       27200  199998.0   51491  2119-02-18 19:49:00
# 139    21445429  16833737       27200  199998.0   51301  2119-02-18 17:58:00
# 119    21445402  16833733       27200  199998.0   51274  2119-02-18 17:58:00
# 152    21445442  16833747       27200  199998.0   51506  2119-02-18 19:49:00
# 150    21445440  16833746       27200  199998.0   51498  2119-02-18 19:49:00
#
#             VALUE  VALUENUM VALUEUOM      FLAG  CATAGORY  VALUENUM_Z-SCORED  \
# 154             4      4.00    mg/dL  abnormal       0.0           8.935176
# 27             15     15.00    mEq/L       NaN       0.0           0.578508
# 98           33.0     33.00       pg  abnormal       0.0           2.480894
# 92            1.0      1.00      NaN       NaN       0.0          -0.641693
# 89           12.8     12.80     g/dL  abnormal       0.0          -0.670068
# 34             27     27.00    mEq/L       NaN       0.0           0.377594
# 36           10.2     10.20    mg/dL       NaN       0.0           2.954342
# 49   See Comments       NaN      NaN       NaN       1.0           0.000000
# 83           37.0     37.00        %  abnormal       0.0          -1.114777
# 42            103    103.00    mEq/L       NaN       0.0           0.019351
# 70            141    141.00    mEq/L       NaN       0.0           0.658737
# 65            4.3      4.30    mEq/L       NaN       0.0           0.500345
# 60            3.6      3.60    mg/dL       NaN       0.0           0.221017
# 59            1.7      1.70    mg/dL       NaN       0.0          -1.347833
# 48            0.9      0.90    mg/dL       NaN       0.0           0.489554
# 76             16     16.00    mg/dL       NaN       0.0           0.603423
# 110            95     95.00       fL       NaN       0.0           1.305191
# 104          34.7     34.70        %       NaN       0.0           1.350207
# 54            109    109.00    mg/dL  abnormal       0.0           1.983991
# 133          3.89      3.89     m/uL  abnormal       0.0          -2.099357
# 116           241    241.00     K/uL       NaN       0.0          -0.219176
# 127          13.7     13.70        %       NaN       0.0          -0.478243
# 141           NEG       NaN    mg/dL       NaN       1.0           0.000000
# 143            SM       NaN      NaN       NaN       3.0           0.000000
# 146           NEG       NaN      NaN       NaN       1.0           0.000000
# 121          29.0     29.00      sec       NaN       0.0           0.073793
# 148           6.5      6.50    units       NaN       0.0           0.707835
# 139           9.6      9.60     K/uL       NaN       0.0           0.911509
# 119          11.7     11.70      sec       NaN       0.0          -1.369342
# 152         Clear       NaN      NaN       NaN       1.0           0.000000
# 150         1.010      1.01                NaN       0.0          -0.808338
#
#      TIMESTEP                          LABEL
# 154       0.0                   Urobilinogen
# 27        0.0                      Anion Gap
# 98        0.0                            MCH
# 92        0.0                        INR(PT)
# 89        0.0                     Hemoglobin
# 34        0.0                    Bicarbonate
# 36        0.0                 Calcium, Total
# 49        0.0  Estimated GFR (MDRD equation)
# 83        0.0                     Hematocrit
# 42        0.0                       Chloride
# 70        0.0                         Sodium
# 65        0.0                      Potassium
# 60        0.0                      Phosphate
# 59        0.0                      Magnesium
# 48        0.0                     Creatinine
# 76        0.0                  Urea Nitrogen
# 110       0.0                            MCV
# 104       0.0                           MCHC
# 54        0.0                        Glucose
# 133       0.0                Red Blood Cells
# 116       0.0                 Platelet Count
# 127       0.0                            RDW
# 141       0.0                      Bilirubin
# 143       0.0                          Blood
# 146       0.0                        Nitrite
# 121       0.0                            PTT
# 148       0.0                             pH
# 139       0.0              White Blood Cells
# 119       0.0                             PT
# 152       0.0               Urine Appearance
# 150       0.0               Specific Gravity

# %%
df_prescriptions[df_prescriptions.HADM_ID==HADM_ID_temp]
# Out:
#           ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  STARTDATE    ENDDATE  \
# 1961425  3189028       27200   199998         NaN 2119-02-18 2119-02-18
# 1961433  3189027       27200   199998         NaN 2119-02-18 2119-02-20
# 1961427  3189033       27200   199998         NaN 2119-02-18 2119-02-20
# 1961432  3189026       27200   199998         NaN 2119-02-18 2119-02-20
# 1961431  3189025       27200   199998         NaN 2119-02-18 2119-02-20
# ...          ...         ...      ...         ...        ...        ...
# 1958140  3190291       27200   199998         NaN 2119-02-23 2119-02-23
# 1958141  3190293       27200   199998         NaN 2119-02-23 2119-02-24
# 1958142  3190292       27200   199998         NaN 2119-02-23 2119-02-24
# 1958143  3190294       27200   199998         NaN 2119-02-23 2119-02-24
# 1958144  3190295       27200   199998         NaN 2119-02-24 2119-02-24
#
#         DRUG_TYPE                         DRUG                DRUG_NAME_POE  \
# 1961425      MAIN          Hydrochlorothiazide          Hydrochlorothiazide
# 1961433      MAIN                    Doxazosin                    Doxazosin
# 1961427      MAIN             Nitroglycerin SL             Nitroglycerin SL
# 1961432      MAIN                   Aspirin EC                   Aspirin EC
# 1961431      MAIN  Sodium Chloride 0.9%  Flush  Sodium Chloride 0.9%  Flush
# ...           ...                          ...                          ...
# 1958140      MAIN          Metoprolol Tartrate          Metoprolol Tartrate
# 1958141      MAIN                     Warfarin                     Warfarin
# 1958142      MAIN                     Warfarin                     Warfarin
# 1958143      MAIN          Metoprolol Tartrate          Metoprolol Tartrate
# 1958144      MAIN           Potassium Chloride           Potassium Chloride
#
#                    DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN           NDC  \
# 1961425          Hydrochlorothiazide            HCTZ25  029832  6.033855e+08
# 1961433                    Doxazosin             DOXA1  015584  9.045523e+08
# 1961427             Nitroglycerin SL            NTG3SL  000474  5.817703e+10
# 1961432                   Aspirin EC          ASAEC325  004381  1.771400e+10
# 1961431  Sodium Chloride 0.9%  Flush         NACLFLUSH     NaN  0.000000e+00
# ...                              ...               ...     ...           ...
# 1958140          Metoprolol Tartrate            METO50  005132  5.107908e+10
# 1958141                     Warfarin             WARF0  014198  5.601698e+07
# 1958142                     Warfarin             WARF1  014198  5.601698e+07
# 1958143          Metoprolol Tartrate            METO25  050631  5.107903e+10
# 1958144           Potassium Chloride            POTA20  022346  5.817702e+10
#
#                   PROD_STRENGTH DOSE_VAL_RX DOSE_UNIT_RX FORM_VAL_DISP  \
# 1961425             25mg Tablet          25           mg             1
# 1961433              1mg Tablet           1           mg             1
# 1961427  0.3mg SL Tablet Bottle         0.3           mg             1
# 1961432               325mg Tab         325           mg             1
# 1961431                 Syringe           3           mL           0.6
# ...                         ...         ...          ...           ...
# 1958140             50mg Tablet          50           mg             1
# 1958141  Check with MD for Dose           1         dose             1
# 1958142              1mg Tablet           3           mg             3
# 1958143             25mg Tablet          75           mg             3
# 1958144        20 mEq SR Tablet          20          mEq             1
#
#         FORM_UNIT_DISP ROUTE
# 1961425            TAB    PO
# 1961433            TAB    PO
# 1961427            TAB    SL
# 1961432            TAB    PO
# 1961431            SYR    IV
# ...                ...   ...
# 1958140            TAB    PO
# 1958141           dose    PO
# 1958142            TAB    PO
# 1958143            TAB    PO
# 1958144            TAB    PO
#
# [104 rows x 19 columns]

# %%
df_procedures_icd[df_procedures_icd.HADM_ID==HADM_ID_temp].merge(df_d_icd_procedures[["ICD9_CODE", "LONG_TITLE"]], how="left", on="ICD9_CODE")
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0  157105       27200   199998        1       3612
# 1  157106       27200   199998        2       3615
# 2  157107       27200   199998        3       3964
#
#                                         LONG_TITLE
# 0  (Aorto)coronary bypass of two coronary arteries
# 1   Single internal mammary-coronary artery bypass
# 2                 Intraoperative cardiac pacemaker
